# %% [markdown]
# # Modelo Híbrido de LLM (Topo a Fundo)
#
# Autor: Daniel Fonseca (adaptado para Colab)
# Data: 15/03/2026
#
# Este notebook integra o projeto inteiro em UM único arquivo Jupyter, carregando e executando todas as camadas do modelo híbrido (L1–L5).

# %% [markdown]
# ## Descrição Filosófica e Objetivo
#
# Este modelo combina:
# - L1: Tábua de Conceitos (Aristóteles)
# - L2: Juízos Kantianos
# - Módulo: Silogismo + Hempel + Popper",
